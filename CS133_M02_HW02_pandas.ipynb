# %% [markdown]
# # Module 2 Homework - Pandas
# Using a dataset from _Wine Spectator_, a wine magazine, we will practice data transformation, grouping, and sorting.

# %% [markdown]
# Created by Ronald Celino (SJSU ID: 016300947)
#
#
# Last updated: 2/21/2026

# %%
csvurl="https://gist.githubusercontent.com/clairehq/" + \
        "79acab35be50eaf1c383948ed3fd1129/raw/407a02139ae1e134992b90b4b2b8c329b3d73a6a/winemag-data-130k-v2.csv"
import pandas as pd
wine = pd.read_csv(csvurl)

# %% [markdown]
# **Data cleaning**
# Notice that the first column is redundant. Part of data analysis is cleaning and removing redundancy. How would you drop the redundant column inplace, that is overwrite the dataframe.

# %%
wine.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %% [markdown]
# #### Question 1: ####
# What is the mean of the points column?

# %%
# Your code here . . .
wine.loc[:, 'points'].mean()
# Out:
# np.float64(88.43403716087269)

# %% [markdown]
# #### Question 2: ####
# How many countries are present in this dataset? (Only count each country once)

# %%
# Your code here . . .
wine['country'].nunique()
# 41 countries present in this dataset
# Out:
# 41

# %% [markdown]
# #### Question 3: ####
# How many times does each country appeared in this dataset? Show each country and the corresponding count (show counts in ascending order)

# %%
# Your code here . . .
wine['country'].value_counts()
# Out:
# country
# US                        27177
# France                    11174
# Italy                     10005
# Spain                      3409
# Portugal                   2963
# Chile                      2258
# Argentina                  1907
# Austria                    1635
# Australia                  1177
# Germany                    1051
# South Africa                737
# New Zealand                 733
# Israel                      259
# Greece                      242
# Canada                      108
# Bulgaria                     68
# Romania                      67
# Uruguay                      61
# Hungary                      61
# Croatia                      44
# Turkey                       43
# Slovenia                     39
# Georgia                      37
# England                      36
# Mexico                       31
# Brazil                       31
# Moldova                      30
# Lebanon                      20
# Morocco                      11
# Peru                          8
# Serbia                        7
# Macedonia                     6
# Czech Republic                6
# Cyprus                        6
# Ukraine                       5
# Luxembourg                    4
# India                         4
# Switzerland                   4
# Armenia                       1
# Bosnia and Herzegovina        1
# Slovakia                      1
# Name: count, dtype: int64

# %% [markdown]
# #### Question 4: ####
# Create a variable `adjusted_price` containing the adjusted price which is the price subtracted by the average price. *This is called **"centering" transformation** - a method commonly used in the preprocessing step before applying various machine learning algorithms.*

# %%
# Your code here . . .
avg_price = wine.loc[:,'price'].mean()
wine['adjusted_price'] = wine['price'] - avg_price
wine
# Out:
#        Unnamed: 0    country  \
# 0               0      Italy
# 1               1   Portugal
# 2               2         US
# 3               3         US
# 4               4         US
# ...           ...        ...
# 65494       65494     France
# 65495       65495  Australia
# 65496       65496         US
# 65497       65497         US
# 65498       65498      Spain
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 65494  Made from young vines from the Vaulorent porti...
# 65495  This is a big, fat, almost sweet-tasting Caber...
# 65496  Much improved over the unripe 2005, Fritz's 20...
# 65497  This wine wears its 15.8% alcohol better than ...
# 65498  A unique take on Manzanilla Sherry, which is o...
#
#                               designation  points  price           province  \
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
# ...                                   ...     ...    ...                ...
# 65494              Fourchaume Premier Cru      90   45.0           Burgundy
# 65495                                 NaN      90   22.0    South Australia
# 65496                              Estate      90   20.0         California
# 65497                            Block 24      90   31.0         California
# 65498                          Manzanilla      90   10.0          Andalucia
#
#                   region_1           region_2         taster_name  \
# 0                     Etna                NaN       Kerin O’Keefe
# 1                      NaN                NaN          Roger Voss
# 2        Willamette Valley  Willamette Valley        Paul Gregutt
# 3      Lake Michigan Shore                NaN  Alexander Peartree
# 4        Willamette Valley  Willamette Valley        Paul Gregutt
# ...                    ...                ...                 ...
# 65494              Chablis                NaN          Roger Voss
# 65495         McLaren Vale                NaN      Joe Czerwinski
# 65496     Dry Creek Valley             Sonoma                 NaN
# 65497          Napa Valley               Napa                 NaN
# 65498                Jerez                NaN   Michael Schachner
#
#       taster_twitter_handle  \
# 0              @kerinokeefe
# 1                @vossroger
# 2               @paulgwine
# 3                       NaN
# 4               @paulgwine
# ...                     ...
# 65494            @vossroger
# 65495                @JoeCz
# 65496                   NaN
# 65497                   NaN
# 65498           @wineschach
#
#                                                    title             variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)         White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2          Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3      St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4      Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# ...                                                  ...                 ...
# 65494  William Fèvre 2005 Fourchaume Premier Cru  (Ch...          Chardonnay
# 65495    Tapestry 2005 Cabernet Sauvignon (McLaren Vale)  Cabernet Sauvignon
# 65496  Fritz 2006 Estate Sauvignon Blanc (Dry Creek V...     Sauvignon Blanc
# 65497       Hendry 2004 Block 24 Primitivo (Napa Valley)           Primitivo
# 65498  Bodegas Dios Baco S.L. NV Manzanilla Sherry (J...              Sherry
#
#                        winery  adjusted_price
# 0                     Nicosia             NaN
# 1         Quinta dos Avidagos      -20.232932
# 2                   Rainstorm      -21.232932
# 3                  St. Julian      -22.232932
# 4                Sweet Cheeks       29.767068
# ...                       ...             ...
# 65494           William Fèvre        9.767068
# 65495                Tapestry      -13.232932
# 65496                   Fritz      -15.232932
# 65497                  Hendry       -4.232932
# 65498  Bodegas Dios Baco S.L.      -25.232932
#
# [65499 rows x 15 columns]

# %% [markdown]
# #### Question 5: ####
# What is the title of the wine that has the highest points-to-price ratio in the dataset?

# %%
# Your code here . . .
# create new column for points to price ratio
wine['ptp_ratio'] = wine['points'] / wine['price']
#wine = wine.sort_values(by=['ptp_ratio'], ascending=True)
#wine.head()

# find title of wine with highest ptp ratio
highest_ptp_ratio = wine.loc[wine['ptp_ratio'].idxmax(), 'title']
highest_ptp_ratio

# reference: highest_robbery_year = alaska_crimes.loc[alaska_crimes['robbery'].idxmax(), 'year']
# alaska_crimes = alaska_crimes[['year', 'state', 'robbery', 'burglary', 'murder']]
# Out:
# 'Bandit NV Merlot (California)'

# %% [markdown]
# #### Question 6: ####
# Create a series `flavor_counts` that contains two values: the number of wines that has the word "tart" in the `description` column and the number of wines that has the word "berries" in the `description` column. The index of the Series should be "Tart" and "Berries" for the corresponding values.

# %%
# Look for the word "tart", not case sensitive, not a substring of another word.
# Same applies to the word "berries"
# Your code here . . .
tart_count = wine['description'].str.contains('tart').sum()
berries_count = wine['description'].str.contains('berries').sum()
# to check count values to compare with series
#print(tart_count) # 4172 count
#print(berries_count) # 3503 count

flavor_counts = pd.Series([tart_count, berries_count], index=['Tart', 'Berries'])
flavor_counts
# Out:
# Tart       4172
# Berries    3503
# dtype: int64

# %% [markdown]
# #### Question 7: ####
# Let's convert the points into simple star ratings. A score of 90 or higher counts as 3 stars, a score of at least 80 but less than 90 is 2 stars. Any other score is 1 star.
#
# Also, any wines from France should automatically get 3 stars, regardless of points.
#
# Add this new column `star_ratings` to the dataframe with the number of stars for each wine in the dataset.

# %%
# Your code here . . .
# assign all wines to 1 star, then filter into 2 or 3 stars afterwards
wine['star_ratings'] = 1

# 3 stars first
wine.loc[wine['points'] >= 90, 'star_ratings'] = 3
wine.loc[wine['country'] == 'France', 'star_ratings'] = 3
# then 2 stars
wine.loc[(wine['points'] >= 80) & (wine['points'] < 90), 'star_ratings'] = 2
wine
# Out:
#        Unnamed: 0    country  \
# 0               0      Italy
# 1               1   Portugal
# 2               2         US
# 3               3         US
# 4               4         US
# ...           ...        ...
# 65494       65494     France
# 65495       65495  Australia
# 65496       65496         US
# 65497       65497         US
# 65498       65498      Spain
#
#                                              description  \
# 0      Aromas include tropical fruit, broom, brimston...
# 1      This is ripe and fruity, a wine that is smooth...
# 2      Tart and snappy, the flavors of lime flesh and...
# 3      Pineapple rind, lemon pith and orange blossom ...
# 4      Much like the regular bottling from 2012, this...
# ...                                                  ...
# 65494  Made from young vines from the Vaulorent porti...
# 65495  This is a big, fat, almost sweet-tasting Caber...
# 65496  Much improved over the unripe 2005, Fritz's 20...
# 65497  This wine wears its 15.8% alcohol better than ...
# 65498  A unique take on Manzanilla Sherry, which is o...
#
#                               designation  points  price           province  \
# 0                            Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                                Avidagos      87   15.0              Douro
# 2                                     NaN      87   14.0             Oregon
# 3                    Reserve Late Harvest      87   13.0           Michigan
# 4      Vintner's Reserve Wild Child Block      87   65.0             Oregon
# ...                                   ...     ...    ...                ...
# 65494              Fourchaume Premier Cru      90   45.0           Burgundy
# 65495                                 NaN      90   22.0    South Australia
# 65496                              Estate      90   20.0         California
# 65497                            Block 24      90   31.0         California
# 65498                          Manzanilla      90   10.0          Andalucia
#
#                   region_1           region_2         taster_name  \
# 0                     Etna                NaN       Kerin O’Keefe
# 1                      NaN                NaN          Roger Voss
# 2        Willamette Valley  Willamette Valley        Paul Gregutt
# 3      Lake Michigan Shore                NaN  Alexander Peartree
# 4        Willamette Valley  Willamette Valley        Paul Gregutt
# ...                    ...                ...                 ...
# 65494              Chablis                NaN          Roger Voss
# 65495         McLaren Vale                NaN      Joe Czerwinski
# 65496     Dry Creek Valley             Sonoma                 NaN
# 65497          Napa Valley               Napa                 NaN
# 65498                Jerez                NaN   Michael Schachner
#
#       taster_twitter_handle  \
# 0              @kerinokeefe
# 1                @vossroger
# 2               @paulgwine
# 3                       NaN
# 4               @paulgwine
# ...                     ...
# 65494            @vossroger
# 65495                @JoeCz
# 65496                   NaN
# 65497                   NaN
# 65498           @wineschach
#
#                                                    title             variety  \
# 0                      Nicosia 2013 Vulkà Bianco  (Etna)         White Blend
# 1          Quinta dos Avidagos 2011 Avidagos Red (Douro)      Portuguese Red
# 2          Rainstorm 2013 Pinot Gris (Willamette Valley)          Pinot Gris
# 3      St. Julian 2013 Reserve Late Harvest Riesling ...            Riesling
# 4      Sweet Cheeks 2012 Vintner's Reserve Wild Child...          Pinot Noir
# ...                                                  ...                 ...
# 65494  William Fèvre 2005 Fourchaume Premier Cru  (Ch...          Chardonnay
# 65495    Tapestry 2005 Cabernet Sauvignon (McLaren Vale)  Cabernet Sauvignon
# 65496  Fritz 2006 Estate Sauvignon Blanc (Dry Creek V...     Sauvignon Blanc
# 65497       Hendry 2004 Block 24 Primitivo (Napa Valley)           Primitivo
# 65498  Bodegas Dios Baco S.L. NV Manzanilla Sherry (J...              Sherry
#
#                        winery  adjusted_price  ptp_ratio  star_ratings
# 0                     Nicosia             NaN        NaN             2
# 1         Quinta dos Avidagos      -20.232932   5.800000             2
# 2                   Rainstorm      -21.232932   6.214286             2
# 3                  St. Julian      -22.232932   6.692308             2
# 4                Sweet Cheeks       29.767068   1.338462             2
# ...                       ...             ...        ...           ...
# 65494           William Fèvre        9.767068   2.000000             3
# 65495                Tapestry      -13.232932   4.090909             3
# 65496                   Fritz      -15.232932   4.500000             3
# 65497                  Hendry       -4.232932   2.903226             3
# 65498  Bodegas Dios Baco S.L.      -25.232932   9.000000             3
#
# [65499 rows x 17 columns]

# %% [markdown]
# #### Question 8: ####
# Who are the most common wine reviewers in the dataset? Create a Series whose index is the taster_twitter_handle category from the dataset, and whose values count how many reviews each person wrote.

# %%
# Your code here . . .
# find value counts for the taster_twitter_handle column
reviewers = wine['taster_twitter_handle'].value_counts()
reviewers

# top 3 are @vossroger, @wineschach, and @kerinokeefe
# Out:
# taster_twitter_handle
# @vossroger          13045
# @wineschach          7752
# @kerinokeefe         5313
# @paulgwine           4851
# @vboone              4696
# @mattkettmann        3035
# @JoeCz               2605
# @wawinereport        2358
# @gordone_cellars     2032
# @AnneInVino          1769
# @laurbuzz             938
# @suskostrzewa         593
# @worldwineguys        465
# @bkfiona               11
# @winewchristina         4
# Name: count, dtype: int64

# %% [markdown]
# #### Question 9: ####
# What combination of countries and varieties are most common? Create a Series whose index is a MultiIndexof {country, variety} pairs. For example, a pinot noir produced in the US should map to {"US", "Pinot Noir"}. Sort the values in the Series in descending order based on wine count.

# %%
# Your code here . . .
country_variety_counts = wine.groupby(['country', 'variety']).size().sort_values(ascending=False)
country_variety_counts
# Out:
# country    variety
# US         Pinot Noir                  4918
#            Cabernet Sauvignon          3649
#            Chardonnay                  3412
# France     Bordeaux-style Red Blend    2380
# Italy      Red Blend                   1870
#                                        ...
# Romania    Rosé                           1
# US         Ugni Blanc                     1
#            Touriga                        1
#            Torrontés                      1
# Argentina  Merlot-Cabernet Franc          1
# Length: 1304, dtype: int64

# %% [markdown]
# #### Question 10 #####
# Create a Series whose index is reviewers and whose values is the average score given out by that reviewer. Hint: you will need the `taster_name` and `points` columns.

# %%
# Your code here . . .
# find mean of points for each taster
avg_scores = wine.groupby('taster_name')['points'].mean()
avg_scores
# Out:
# taster_name
# Alexander Peartree    86.014286
# Anna Lee C. Iijima    88.380506
# Anne Krebiehl MW      90.587903
# Carrie Dykes          86.644444
# Christina Pickard     89.500000
# Fiona Adams           87.090909
# Jeff Jenssen          88.273504
# Jim Gordon            88.604331
# Joe Czerwinski        88.519770
# Kerin O’Keefe         88.827969
# Lauren Buzzeo         87.831557
# Matt Kettmann         90.021087
# Michael Schachner     86.904541
# Mike DeSimone         89.030303
# Paul Gregutt          89.095032
# Roger Voss            88.678957
# Sean P. Sullivan      88.666243
# Susan Kostrzewa       86.408094
# Virginie Boone        89.229557
# Name: points, dtype: float64
